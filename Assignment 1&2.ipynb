# %% [markdown]
# # Assignment 1: Python Basics and Data Types

# %% [markdown]
# # Variable Manipulation

# %% [markdown]
# # Define Variable

# %%
student_name = "Pavan"
age = 18
gpa = 9.4
subjects = ["History", "Biology", "Math","python"]

# %% [markdown]
# # Convert age from years to months

# %%
age_in_months = age * 12

# %% [markdown]
# # Result =

# %%
print("Age in months:", age_in_months)
# Out:
# Age in months: 216

# %% [markdown]
# # Concatenate and print sentence

# %%
print("Student Name:", student_name)
print("Age:", age)
print("GPA:", gpa)
print("Subjects:", subjects)
# Out:
# Student Name: Pavan
# Age: 18
# GPA: 9.4
# Subjects: ['History', 'Biology', 'Math', 'python']

# %%
sentence = student_name + " is " + str(age) + " years old with GPA " + str(gpa)
print(sentence)
# Out:
# Pavan is 18 years old with GPA 9.4

# %% [markdown]
# # 2. Type Conversion Practice

# %%
float_a = 5.7

# %% [markdown]
# # Convert float to integer

# %%
int_a = int(float_a)

# %%
print("\nOriginal Float Value:", float_a)
print("Converted Integer Value:", int_a)
# Out:
# Original Float Value: 5.7
# Converted Integer Value: 5

# %%
print("Explanation: The decimal part is removed when converting float to int.")
# Out:
# Explanation: The decimal part is removed when converting float to int.

# %% [markdown]
# # Assignment 2 : Data Structure - List,Tuple,Set & Dictionary

# %% [markdown]
# # 1. Working With Lists

# %% [markdown]
# # Create a list of integers

# %%
num = [1,2,3,4,5,6,7]

# %%
print("Original List = ", num)
# Out:
# Original List =  [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# # Append a new number

# %%
num.append(8)

# %%
print("After Appending :-" , num)
# Out:
# After Appending :- [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# # Insert a number at specific index

# %%
num.insert(2, 3.5)

# %%
print("After Insrting :- ", num)
# Out:
# After Insrting :-  [1, 2, 3.5, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# # Remove Duplicates

# %%
num_list = list(set(num))

# %%
print("After Removing Duplicates :-",num)
# Out:
# After Removing Duplicates :- [1, 2, 3.5, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# # 2. Tuple Manipulation

# %% [markdown]
# # Define tuple of 5 colors

# %%
colors = ("red","White","Grey","Pink","Black")

# %%
print("Original Tuple", colors)
# Out:
# Original Tuple ('red', 'White', 'Grey', 'Pink', 'Black')

# %% [markdown]
# # Tuples cannot be modified

# %%
print("Tuples are immutable, so new items cannot be added directly.")
# Out:
# Tuples are immutable, so new items cannot be added directly.

# %% [markdown]
# # Convert tuple to list

# %%
colors_l =  list(colors)

# %% [markdown]
# # Add new color

# %%
colors_l.append('Light red')

# %% [markdown]
# # Convert back to tuple

# %%
colors = tuple(colors_l)

# %%
print("Updated Tuple :-", colors)
# Out:
# Updated Tuple :- ('red', 'White', 'Grey', 'Pink', 'Black', 'Light red', 'Light red')

# %% [markdown]
# # 3. Set Operations

# %% [markdown]
#  # Create two sets

# %%
set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7, 8}

# %%
set1
# Out:
# {1, 2, 3, 4, 5}

# %%
set2
# Out:
# {4, 5, 6, 7, 8}

# %% [markdown]
# # union

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %% [markdown]
# # intersection

# %%
set1.intersection(set2)
# Out:
# {4, 5}

# %% [markdown]
# # Diffrence

# %%
set1.difference(set2)
# Out:
# {1, 2, 3}

# %% [markdown]
# # Remove one element and add new element

# %%
set1.remove(3)
set1.add(10)

# %%
print("Updated set 1 = ",set1)
# Out:
# Updated set 1 =  {1, 2, 4, 5, 10}

# %% [markdown]
# # 4. Dictionary Practice

# %% [markdown]
# # Create dictionary

# %%
library = {"Maths": 5, "Biology": 3, "Machine Learning": 4}

# %%
print("Original library Dict", library)
# Out:
# Original library Dict {'Maths': 5, 'Biology': 3, 'Machine Learning': 4}

# %% [markdown]
# # Update count after borrowing

# %%
library["Maths"] = 6

# %%
print("Updated Dictionary", library)
# Out:
# Updated Dictionary {'Maths': 6, 'Biology': 3, 'Machine Learning': 4}
